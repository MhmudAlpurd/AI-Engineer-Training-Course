# %%
from IPython.display import Image
Image(filename='py_slides/17.png', width="500")

# %%
Image(filename='py_slides/18.png', width="500")

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
Image(filename='py_slides/19.png', width="500")

# %%
name = "Naghi"
print(name)
# Out:
# Naghi

# %%
Image(filename='py_slides/20.png', width="500")

# %%
# image resolution is X!
name = "Ali"
print('Your first name is : ', name)
# Out:
# Your first name is :  Ali

# %%
#Sensor / measuring temperature : temperature
temp = 43
print('Temperature is :' , temp)
# Out:
# Temperature is : + 43

# %%
temp = 18
text = 'Temperature  is : ' + 18 + 'centigrade'
print(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 temp = 18
# ----> 2 text = 'Temperature  is : ' + 18 + 'centigrade'
#       3 print(text)
#
# TypeError: can only concatenate str (not "int") to str

# %%
Image(filename='py_slides/21.png', width="500")

# %%
age = 23
age = 34
print(age)
# Out:
# 34

# %%
Image(filename='py_slides/22.png', width="500")

# %%
name_1, name_2, name_3 = 'hassan', 'kobra', 'Ahmad'
print(name_1)
print(name_2)
print(name_3)
# Out:
# hassan
# kobra
# Ahmad

# %%
Image(filename='py_slides/23.png', width="500")

# %%
family_1 = family_2 = family_3 = 'Alavi'
print(family_1)
print(family_2)
print(family_3)
# Out:
# Alavi
# Alavi
# Alavi

# %%
family_1 = 'Rostami'
print(family_1)
print(family_2)
print(family_3)
# Out:
# Rostami
# Alavi
# Alavi

# %%
print(id(family_1))
print(id(family_2))
print(id(family_3))
# Out:
# 138123989235312
# 138123979595440
# 138123979595440

# %%
Image(filename='py_slides/24.png', width="500")

# %%
lst = [10, 20, 30]
a, b, c = lst
print('first item: ', a)
print('second item: ', b)
print('third item: ', c)
# Out:
# first item:  10
# second item:  20
# third item:  30

# %%
Image(filename='py_slides/25.png', width="500")

# %%
age = 25

# %%
2age = 2 * age
# Out:
#   Cell In[38], line 1
#     2age = 2 * age
#     ^
# SyntaxError: invalid decimal literal

# %%
#ALLOWED!
#a-z
# A-Z
#_

# %%
#NOT ALLOWED
#0_9
#reserved: if else, , return, True, False, None, ...
#با سمبل های خاص مثل % و $ و #  @

# %%
فایل = 'PATH'

# %%
print(فایل)
# Out:
# PATH

# %%
last name = 'Taghavi'
# Out:
#   Cell In[42], line 1
#     last name = 'Taghavi'
#          ^
# SyntaxError: invalid syntax

# %%
# %address = 'Tehran'
# Out:
# UsageError: Line magic function `%address` not found.

# %%
name = 'Amin'
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 name = 'Amin'
# ----> 2 print(Name)
#
# NameError: name 'Name' is not defined

# %%
#name != Name

# %%
Image(filename='py_slides/26.png', width="500")

# %% [markdown]
# ## int ---> Sahih --- > 1, -1, -5
# ## float -->  Ashari ---->  0.5, 1.5, -0.35
# ## str ---> Reshteh, String ---> 'Text', 'my name is Ali'
# ## bool ---> True, False
# ## list --- > [1, 2, 3]
# ## tuple ---> (1, 2, 3)
# ## dict --->{"name": "ali", "family": "alavi"}
# ## set ----> {1, 2, 3}

# %%
a = 10
b = 3.14
c = "Laptop"
e = True
f = [1, 2, 3]
g = (4, 5, 6)
h = {"name": "ali", "family":"alavi"}
i = {1, 2, 3}

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
print(type(e))
# Out:
# <class 'bool'>

# %%
print(type(g))
# Out:
# <class 'tuple'>

# %%
print(type(h))
# Out:
# <class 'dict'>

# %%
print(type(i))
# Out:
# <class 'set'>

# %%
v = 4j
print(type(v))
# Out:
# <class 'complex'>

# %%
b = None
print(type(b))
# Out:
# <class 'NoneType'>

# %%
lst2 = []
print(type(lst2))
# Out:
# <class 'list'>

# %%
print('yek')
 print('do')
# Out:
#   Cell In[61], line 2
#     print('do')
#     ^
# IndentationError: unexpected indent
