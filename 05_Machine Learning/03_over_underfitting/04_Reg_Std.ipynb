# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X= df.drop('sales', axis=1)
y= df['sales']

# %%
from sklearn.preprocessing import  PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(degree=4, include_bias=False)

# %%
poly_features = polynomial_converter.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features,y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
#scaler.fit(X_test)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Ridge
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=3)

# %%
ridge_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=3)

# %% [markdown]
# #rmse without standardization and ridge
#
# #rmse train
# [1.7345941243293763,
#  0.5879574085292231,
#  0.43393443569020695,
#  0.35170836883993567,
#  0.25093429640264686,
#  0.19858751396261698]
#
# #rmse test
#  [1.5161519375993877,
#  0.6646431757269282,
#  0.580328682523338,
#  0.5077742639780601,
#  2.5758223676449745,
#  4.315624016238058]

# %%
y_pred = ridge_model.predict(X_test)
y_pred_train = ridge_model.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
MAE_test = mean_absolute_error(y_test, y_pred)
MSE_test = mean_squared_error(y_test, y_pred)
RMSE_test = np.sqrt(MSE_test)

# %%
MSE_train = mean_squared_error(y_train, y_pred_train)
RMSE_train = np.sqrt(MSE_train)

# %%
MAE_test
# Out:
# 0.6451782747460065

# %%
MSE_test
# Out:
# 0.6484332797140676

# %%
RMSE_test
# Out:
# 0.8052535499543405

# %%
RMSE_train
# Out:
# 0.7075747789263124

# %%
RMSE_WITHOUT_ST_REG_TRAIN = 0.43393443569020695
RMSE_WITHOUT_ST_REG_TEST = 0.580328682523338

# %%
RMSE_test = 0.8052535499543405
RMSE_train = 0.7075747789263124

# %%
delta_without_st_reg = RMSE_WITHOUT_ST_REG_TRAIN - RMSE_WITHOUT_ST_REG_TEST
delta_without_st_reg
# Out:
# -0.14639424683313107

# %%
delta_st_reg = RMSE_train - RMSE_test
delta_st_reg
# Out:
# -0.09767877102802813

# %%
from sklearn.linear_model import LassoCV

# %%
lasso_cv_model = LassoCV(eps=0.01, n_alphas=100)

# %%
lasso_cv_model.fit(X_train, y_train)
# Out:
# LassoCV(eps=0.01)

# %%
y_pred_lasso = lasso_cv_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
MSE_test = mean_squared_error(y_test, y_pred_lasso)
RMSE_test = np.sqrt(MSE_test)

# %%
RMSE_test
# Out:
# 0.7456035333813704

# %%
#Elastic!
